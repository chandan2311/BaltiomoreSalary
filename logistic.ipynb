# %% [markdown]
# <a href="https://colab.research.google.com/github/chandan2311/BaltiomoreSalary/blob/main/logistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
! git clone "titanic.csv"
# Out:
# Cloning into 'a08a1080b88344b0c8a7'...
# remote: Enumerating objects: 35, done.
# remote: Total 35 (delta 0), reused 0 (delta 0), pack-reused 35
# Receiving objects: 100% (35/35), 5.54 KiB | 5.54 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
df=pd.read_csv("/content/a08a1080b88344b0c8a7/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species'] = df['species'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    string
# dtypes: float64(4), string(1)
# memory usage: 6.0 KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['species']=encoder.fit_transform(df['species'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df1=pd.read_csv("/content/tested.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
X=df1['Age']

# %%
Y=df1['Survived']

# %%
plt.scatter(X,Y)

# %%
class LogisticRegression:
  def __init__(self, x, y):
    self.x = x
    self.y = y
    self.n = len(x)
    self.a = 0
    self.b = 0
    self.alpha = 0.01
    self.epoch = 100
    self.cost_list = []

  def sigmoid(self, x):
    return 1/(1 + np.exp(-x))

  def train(self):
    for i in range(self.epoch):
      Z = self.a*self.x + self.b
      A = self.sigmoid(Z)

      # cost function
      cost = -(1/self.n)*np.sum( self.y*np.log(A) + (1-self.y)*np.log(1-A))

      # Gradient Descent

      da = (1/self.n)*np.dot(A-self.y, self.x)
      db = (1/self.n)*np.sum(A - self.y)

      self.a =self.a- self.alpha*da
      self.b = self.b-self.alpha*db

      # Keeping track of our cost function value
      self.cost_list.append(cost)

      print("cost after ", i, "iteration is : ", cost)

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

model = LogisticRegression(X_train, Y_train)
model.epoch=1000
model.alpha=0.003
model.train()
# Out:
# cost after  0 iteration is :  0.6931471805599453
# cost after  1 iteration is :  0.6540273059478041
# cost after  2 iteration is :  0.6169594178686315
# cost after  3 iteration is :  0.5818305869314429
# cost after  4 iteration is :  0.548530727375629
# cost after  5 iteration is :  0.516953312469362
# cost after  6 iteration is :  0.48699591300087897
# cost after  7 iteration is :  0.4585605789470981
# cost after  8 iteration is :  0.43155408559351066
# cost after  9 iteration is :  0.40588806525945936
# cost after  10 iteration is :  0.3814790447298796
# cost after  11 iteration is :  0.3582484068355148
# cost after  12 iteration is :  0.3361222926251165
# cost after  13 iteration is :  0.31503145843996205
# cost after  14 iteration is :  0.2949111000810303
# cost after  15 iteration is :  0.27570065425190526
# cost after  16 iteration is :  0.2573435856265548
# cost after  17 iteration is :  0.2397871662617301
# cost after  18 iteration is :  0.22298225265867277
# ...

# %%
print(X)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
print(Y)
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
print(X_train)
# Out:
# 109    18.5
# 176    20.0
# 366     NaN
# 407    50.0
# 280    23.0
#        ...
# 71     21.0
# 106    21.0
# 270    46.0
# 348    24.0
# 102     NaN
# Name: Age, Length: 280, dtype: float64

# %%
print(Y_train)
# Out:
# 109    0
# 176    1
# 366    0
# 407    0
# 280    1
#       ..
# 71     0
# 106    0
# 270    0
# 348    0
# 102    0
# Name: Survived, Length: 280, dtype: int64

# %%
X=df['sepal_length']

# %%
Y=df['species']

# %%
model1=LogisticRegression(X,Y)

# %%
model1.epoch=10000
model1.train()
# Out:
# cost after  0 iteration is :  0.6931471805599454
# cost after  1 iteration is :  0.5771140578540622
# cost after  2 iteration is :  0.48075931837986313
# cost after  3 iteration is :  0.4003505335074893
# cost after  4 iteration is :  0.3327426329645823
# cost after  5 iteration is :  0.2753864655160123
# cost after  6 iteration is :  0.22626016647965022
# cost after  7 iteration is :  0.18377651588095079
# cost after  8 iteration is :  0.14669309734739416
# cost after  9 iteration is :  0.11403560984308182
# cost after  10 iteration is :  0.08503636426958129
# cost after  11 iteration is :  0.05908652977970803
# cost after  12 iteration is :  0.03569965418681714
# cost after  13 iteration is :  0.014483988204144113
# cost after  14 iteration is :  -0.004878485824357692
# cost after  15 iteration is :  -0.022647981543934843
# cost after  16 iteration is :  -0.039039059854641116
# cost after  17 iteration is :  -0.05422995307293926
# ...

# %%
model.train()
# Out:
# cost after  0 iteration is :  -1.6791332982472684
# cost after  1 iteration is :  -1.6838896849729514
# cost after  2 iteration is :  -1.6886460642700345
# cost after  3 iteration is :  -1.693402439064477
# cost after  4 iteration is :  -1.6981588084474475
# cost after  5 iteration is :  -1.7029151714317083
# cost after  6 iteration is :  -1.7076715305357548
# cost after  7 iteration is :  -1.7124278847945777
# cost after  8 iteration is :  -1.7171842326338642
# cost after  9 iteration is :  -1.7219405775258607
# cost after  10 iteration is :  -1.726696917659017
# cost after  11 iteration is :  -1.7314532525865007
# cost after  12 iteration is :  -1.7362095843863523
# cost after  13 iteration is :  -1.7409659120883518
# cost after  14 iteration is :  -1.7457222355028659
# cost after  15 iteration is :  -1.7504785535782605
# cost after  16 iteration is :  -1.755234870921572
# cost after  17 iteration is :  -1.7599911830545327
# cost after  18 iteration is :  -1.7647474921780397
# ...

# %%
df3=pd.read_csv("/content/penguins_binary_classification.csv")

# %%
df3
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 269  Gentoo     Biscoe            47.2           13.7              214.0
# 270  Gentoo     Biscoe            46.8           14.3              215.0
# 271  Gentoo     Biscoe            50.4           15.7              222.0
# 272  Gentoo     Biscoe            45.2           14.8              212.0
# 273  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g  year
# 0         3750.0  2007
# 1         3800.0  2007
# ...

# %%
df3.shape
# Out:
# (274, 7)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            274 non-null    object
#  1   island             274 non-null    object
#  2   bill_length_mm     274 non-null    float64
#  3   bill_depth_mm      274 non-null    float64
#  4   flipper_length_mm  274 non-null    float64
#  5   body_mass_g        274 non-null    float64
#  6   year               274 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 15.1+ KB

# %%
df3['species']=df3['species'].astype('string')

# %%
df3
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 269  Gentoo     Biscoe            47.2           13.7              214.0
# 270  Gentoo     Biscoe            46.8           14.3              215.0
# 271  Gentoo     Biscoe            50.4           15.7              222.0
# 272  Gentoo     Biscoe            45.2           14.8              212.0
# 273  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g  year
# 0         3750.0  2007
# 1         3800.0  2007
# ...

# %%
df3['species']=encoder.fit_transform(df3['species'])

# %%
df3
# Out:
#      species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0  Torgersen            39.1           18.7              181.0
# 1          0  Torgersen            39.5           17.4              186.0
# 2          0  Torgersen            40.3           18.0              195.0
# 3          0  Torgersen            36.7           19.3              193.0
# 4          0  Torgersen            39.3           20.6              190.0
# ..       ...        ...             ...            ...                ...
# 269        1     Biscoe            47.2           13.7              214.0
# 270        1     Biscoe            46.8           14.3              215.0
# 271        1     Biscoe            50.4           15.7              222.0
# 272        1     Biscoe            45.2           14.8              212.0
# 273        1     Biscoe            49.9           16.1              213.0
#
#      body_mass_g  year
# 0         3750.0  2007
# 1         3800.0  2007
# ...

# %%
X1=df3['bill_length_mm']

# %%
Y2=df3['species']

# %%
model4=LogisticRegression(X1,Y2)

# %%
model4.epoch=10000

# %%
model4.train()
# Out:
# Streaming output truncated to the last 5000 lines.
# cost after  5000 iteration is :  2.144061877715273
# cost after  5001 iteration is :  2.07320439589572
# cost after  5002 iteration is :  2.144032838984547
# cost after  5003 iteration is :  2.073129365661173
# cost after  5004 iteration is :  2.1440037986511125
# cost after  5005 iteration is :  2.0730543360010096
# cost after  5006 iteration is :  2.1439747567143943
# cost after  5007 iteration is :  2.072979306915722
# cost after  5008 iteration is :  2.143945713173822
# cost after  5009 iteration is :  2.072904278405801
# cost after  5010 iteration is :  2.1439166680288206
# cost after  5011 iteration is :  2.072829250471742
# cost after  5012 iteration is :  2.1438876212788176
# cost after  5013 iteration is :  2.0727542231140386
# cost after  5014 iteration is :  2.1438585729232362
# cost after  5015 iteration is :  2.072679196333184
# cost after  5016 iteration is :  2.143829522961506
# ...

# %%
plt.scatter(X1, Y2)
N = np.array(range(5000))/1000
P = model4.a*N+model.b
P = model4.sigmoid(P)
plt.plot(N, P,color="red")

# %%
plot_decision_boundary(model4.a, model4.b, X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-85ff9d52ae79> in <cell line: 1>()
# ----> 1 plot_decision_boundary(model4.a, model4.b, X,Y)
#
# NameError: name 'plot_decision_boundary' is not defined

# %%
plt.scatter(X1,Y2

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(X1,Y2)
# Assuming model.a and model.b are the coefficients of the linear model
x_values = np.array(range(274))  # Replace this with your actual x values
P = model4.a * x_values + model4.b
P_sigmoid = 1 / (1 + np.exp(-P))  # Use the sigmoid function directly

# Scatter plot (if you have data points to scatter)
# plt.scatter(x_values, your_y_values, label='Data Points')

# Plot the sigmoid function
plt.plot(x_values, P_sigmoid, color="red", label='Sigmoid Function')

# Add labels and legend
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.legend()

# Show the plot
plt.show()
